# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math
import random

# %%
#read imgage
img = cv2.imread("house.jpg")
#bgr to rgb
img_color = img[...,::-1]
#display img
plt.imshow(img_color)
plt.axis('off')
plt.show()

# %%
#conv to gray
img_gray = cv2.imread("house.jpg" , 0)
plt.imshow(img_gray , cmap = "gray")
plt.axis('off')
plt.show()

# %%
img_gray.shape
# Out:
# (506, 900)

# %%
#crop img
img_crop = img_gray[200:380 , 380:470]
plt.imshow(img_crop , cmap = "gray")
plt.axis('off')
plt.show()

# %%
img_2_gray = cv2.imread("dog.jpg" , 0)
plt.imshow(img_2_gray , cmap = "gray")
plt.axis('off')
plt.show()

# %%
img_2_gray.shape
# Out:
# (334, 500)

# %%
img_gray = cv2.resize(img_gray ,(500,334))

# %%
add = cv2.add(img_gray , img_2_gray)
plt.imshow(add_easy , cmap = "gray")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 add = cv2.add(img_gray , img_2_gray)
# ----> 2 plt.imshow(add_easy , cmap = "gray")
#       3 plt.axis('off')
#       4 plt.show()
#
# NameError: name 'add_easy' is not defined

# %%
sub = cv2.subtract(img_gray , img_2_gray)
plt.imshow(sub , cmap = "gray")
plt.axis('off')
plt.show()

# %%
img_and = cv2.bitwise_and(img_gray , img_2_gray)
plt.imshow(img_and , cmap = "gray")
plt.axis('off')
plt.show()

# %%
img_or = cv2.bitwise_or(img_gray , img_2_gray)
plt.imshow(img_or , cmap = "gray")
plt.axis('off')
plt.show()

# %%
img_not = cv2.bitwise_not(img_gray)
plt.imshow(img_not , cmap = "gray")
plt.axis('off')
plt.show()

# %%
img_xor = cv2.bitwise_xor(img_gray , img_2_gray)
plt.imshow(img_xor , cmap = "gray")
plt.axis('off')
plt.show()
